# %%
import numpy as np
import imageio
import scipy.ndimage
# %matplotlib inline 
import matplotlib.pyplot as plt

def dodge(front,back):
    result=front*255/(255-back) 
    result[result>255]=255
    result[back==255]=255
    return result.astype('uint8')


def grayscale(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

# %%
img =r"C:\Users\manju\Music\pencil-sketch-master\pencil-sketch\paapu.jpeg"

# %%
s = imageio.imread(img)
g=grayscale(s)
i = 255-g
b = scipy.ndimage.filters.gaussian_filter(i,sigma=10)
r= dodge(b,g)
plt.title('Pencil_sketch', fontsize=16)
plt.imshow(r, cmap="gray")
plt.gca().axes.get_yaxis().set_visible(False)
plt.gca().axes.get_xaxis().set_visible(False)
plt.show()
plt.imsave('sketch.png', r, cmap='gray', vmin=0, vmax=255)
# Out:
# C:\Users\manju\AppData\Local\Temp/ipykernel_12636/321958966.py:8: RuntimeWarning: divide by zero encountered in true_divide
#   result=front*255/(255-back)
